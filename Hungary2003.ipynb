# %%
import numpy as np
import pandas as pd
import matplotlib as plt

pd.set_option('display.max_rows', None)

# %%
df = pd.read_csv('C:\\Users\\Aitor\\Desktop\\Proyectos\\Formula 1\\Data\\lap_times.csv')
df_Hungary = df[df['raceId'] == 120]
df_Alo = df_Hungary[df_Hungary['driverId'] == 4]
df_Alo
# Out:
#         raceId  driverId  lap  position      time  milliseconds
# 242639     120         4    1         1  1:29.400         89400
# 242640     120         4    2         1  1:25.490         85490
# 242641     120         4    3         1  1:24.979         84979
# 242642     120         4    4         1  1:25.085         85085
# 242643     120         4    5         1  1:24.384         84384
# 242644     120         4    6         1  1:23.984         83984
# 242645     120         4    7         1  1:23.840         83840
# 242646     120         4    8         1  1:23.689         83689
# 242647     120         4    9         1  1:23.741         83741
# 242648     120         4   10         1  1:23.437         83437
# 242649     120         4   11         1  1:23.043         83043
# 242650     120         4   12         1  1:23.196         83196
# 242651     120         4   13         1  1:26.457         86457
# 242652     120         4   14         2  1:45.000        105000
# ...

# %%
df_Alo.describe()
# Out:
#        raceId  driverId        lap   position   milliseconds
# count    70.0      70.0  70.000000  70.000000      70.000000
# mean    120.0       4.0  35.500000   1.014286   84878.000000
# std       0.0       0.0  20.351085   0.119523    4541.777737
# min     120.0       4.0   1.000000   1.000000   82565.000000
# 25%     120.0       4.0  18.250000   1.000000   83422.000000
# 50%     120.0       4.0  35.500000   1.000000   83754.500000
# 75%     120.0       4.0  52.750000   1.000000   84200.250000
# max     120.0       4.0  70.000000   2.000000  106642.000000

# %%
df_Alo.shape
# Out:
# (70, 6)

# %%
df_Alo['milliseconds'] = df_Alo['milliseconds'] / 1000
# Rename the 'OldColumn' to 'NewColumn'
df_Alo.rename(columns={'milliseconds': 'Seconds'}, inplace=True)
df_Alo
# Out:
# C:\Users\Aitor\AppData\Local\Temp\ipykernel_1848\413544390.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_Alo['milliseconds'] = df_Alo['milliseconds'] / 1000
# C:\Users\Aitor\AppData\Local\Temp\ipykernel_1848\413544390.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_Alo.rename(columns={'milliseconds': 'Seconds'}, inplace=True)
#         raceId  driverId  lap  position      time  Seconds
# 242639     120         4    1         1  1:29.400   89.400
# 242640     120         4    2         1  1:25.490   85.490
# ...

# %%
df_Alo.plot(x='lap', y='Seconds', kind='line')
# Out:
# <Axes: xlabel='lap'>

# %%
df_Hungary['milliseconds'] = df_Hungary['milliseconds']/1000
df_Hungary.rename(columns={'milliseconds': 'Seconds'}, inplace=True)
# Out:
# C:\Users\Aitor\AppData\Local\Temp\ipykernel_1848\3522698799.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_Hungary['milliseconds'] = df_Hungary['milliseconds']/1000
# C:\Users\Aitor\AppData\Local\Temp\ipykernel_1848\3522698799.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_Hungary.rename(columns={'milliseconds': 'Seconds'}, inplace=True)
